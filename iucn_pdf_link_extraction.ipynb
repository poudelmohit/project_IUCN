# %% [markdown]
# <a href="https://colab.research.google.com/github/poudelmohit/project_IUCN/blob/main/iucn_pdf_link_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Steps (Workflow):
#
#
# 1.   Mouting directory and installing required libraries
# 2.   Obtain a list of mammals (mammals diversity database)
# 3.   obtain IUCN data (pdf) download link for each of those species
# 4.   Download IUCN-report of each species using the download link obtained
# 5.   Extract IUCN information into a dataframe by reading pdfs
# 6.   genomic approaches

# %% [markdown]
# # 1.1 Mounting Directory:

# %%
from google.colab import drive
MOUNTPOINT = '/content/drive'
drive.mount(MOUNTPOINT)

import os
directory = os.path.join(MOUNTPOINT,'MyDrive','Colab Notebooks','LAB','project_IUCN')
os.chdir(directory)
# Out:
# Mounted at /content/drive

# %%
! ls
# Out:
# all_download_links.csv	iucn_extracted_raw_data.csv	iucn_reports
# data_extraction.py	iucn_pdf_link_extraction.ipynb	mammals_list.txt

# %% [markdown]
# # 1.2 Importing libraries:

# %%
! pip install selenium
# import selenium
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd

import re # regex to manipulate texts

! pip install pdfplumber
import pdfplumber # to work with pdf (IUCN reports)
# Out:
# Collecting selenium
#   Downloading selenium-4.25.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.3)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.26.2-py3-none-any.whl.metadata (8.6 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2024.8.30)
# Requirement already satisfied: typing_extensions~=4.9 in /usr/local/lib/python3.10/dist-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (24.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.10)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.2.2)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Downloading selenium-4.25.0-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 49.2 MB/s eta 0:00:00
# Downloading trio-0.26.2-py3-none-any.whl (475 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 476.0/476.0 kB 29.1 MB/s eta 0:00:00
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.14.0 outcome-1.3.0.post0 selenium-4.25.0 trio-0.26.2 trio-websocket-0.11.1 wsproto-1.2.0
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.4-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.7 MB/s eta 0:00:00
# Collecting pdfminer.six==20231228 (from pdfplumber)
#   Downloading pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (10.4.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber) (43.0.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.22)
# Downloading pdfplumber-0.11.4-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 4.2 MB/s eta 0:00:00
# Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 57.0 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 73.4 MB/s eta 0:00:00
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20231228 pdfplumber-0.11.4 pypdfium2-4.30.0

# %% [markdown]
# # 2. Obtaining the list of mammals from Mammal Diversity Database:

# %%
url =  'https://www.mammaldiversity.org/explore.html'
mammal_database = pd.read_html(url)[0]

mammal_database['scientific_name'] = mammal_database['Genus'] + " " + mammal_database["Species"]

# Convert DataFrame column to a list
mammals_list = mammal_database['scientific_name'].to_list()

# Correct the spelling error in the list
mammals_list = [species.replace('Caluromysiops irruptus', 'Caluromysiops irrupta') for species in mammals_list]


# Save to a text file, comma-separated
with open('mammals_list.txt', 'w') as file:
    file.write(','.join(mammals_list))

# %% [markdown]
# #### some issues here:
# ##### a. this list have some incorrect species name (while comparing with IUCN site)
# ###### b. this list has all names in a single line, which needs to be fixed while reading the file

# %%
# let's check the number of species we have:

with open('mammals_list.txt', 'r') as file:
    total_entries = sum(len(line.split(',')) for line in file)

print(f"Total number of entries: {total_entries}")
# Out:
# Total number of entries: 6753

# %% [markdown]
# #### 6753 entries are present currently.

# %% [markdown]
# # 3.1 Creating a function to obtain IUCN data download link:

# %%
# ! pip install selenium
# might require installation.



def search_iucn_species(species_name):
    """
    Searches for a species on the IUCN Red List website and retrieves the common name and a download link of the IUCN species assessment report pdf.

    Args:
        species_name (str): The name of the species to search for, preferentially scientific name.

    Returns:
        dict(A dictionary containing):
            - "scientific_name": The input species name.
            - "common_name": The headline text of the species page.
            - "download_link": The URL of the first available download button, or None if no download buttons are found.
    """

    # Set up Chrome options
    chrome_options = Options()
    chrome_options.add_argument("--headless")
    chrome_options.add_argument("--no-sandbox")
    chrome_options.add_argument("--disable-dev-shm-usage")

    # Initialize the WebDriver with Chrome options
    driver = webdriver.Chrome(options=chrome_options)

    try:
        # Open the IUCN Red List website
        driver.get("https://www.iucnredlist.org/")

        # Find the search box element using the class attribute
        search_box = driver.find_element("css selector", "input.search.search--site")

        # Type the search query (species name) and hit Enter
        search_box.send_keys(species_name)
        search_box.send_keys(Keys.RETURN)

        # Wait for the search results to load
        time.sleep(1)

        # Find and click on the first 'View' link with the class "link--faux"
        view_link = driver.find_element("css selector", "a.link--faux")
        view_link.click()

        # Wait for the species page to load after clicking the link
        time.sleep(1)

        # Find the h1 element with the class "headline__title"
        headline = driver.find_element("css selector", "h1.headline__title")
        headline_text = headline.text

        # Find and click the download button with the specified class
        download_button = driver.find_element("name", "download_search_results")
        download_button.click()

        # Wait for the download options to appear
        time.sleep(1)

        # Find all 'link--download' buttons
        download_buttons = driver.find_elements("css selector", "a.link--download")
        if download_buttons:
            # Get the href attribute of the first download button
            first_href = download_buttons[0].get_attribute("href")
        else:
            first_href = None
            print(f"No download buttons found for species: {species_name}")

        # Create a dictionary with the headline and first href
        result = {
            "scientific_name": species_name,
            "common_name": headline_text,
            "download_link": first_href
        }
        return result

    except Exception as e:
        # Print the error message and skip to the next species
        print(f"Error searching for species: {species_name}")
        return {
            "scientific_name": species_name,
            "common_name": None,
            "download_link": None
        }

    finally:
        # Close the browser
        driver.quit()

# %%
# just a test:
print(search_iucn_species("Didelphis virginiana"))
# Out:
# {'scientific_name': 'Didelphis virginiana', 'common_name': 'Virginia Opossum', 'download_link': 'https://www.iucnredlist.org/species/pdf/22176259'}

# %% [markdown]
# #### This function works well. Now, I need to iterate it over the list of mammals (or any species) I have, to get the download link of the IUCN data.
#
# #### Although, currently I have >6k entries, I will work with only ~1000 first, just to check the codes/pipelines.

# %% [markdown]
# # 3.2 Using the function to obtain the download links:

# %%
import pandas as pd

# Read the single line from the file mammals_list
with open('mammals_list.txt', 'r') as file:
    # Read the single line and split into a list of species names using comma as the separator
    mammals_list = file.readline().split(',')

# Loop over each species and its index in the mammals_list
for index, species in enumerate(mammals_list):
    species = species.strip()  # Remove any leading/trailing whitespace
    print(f"Working on species: {species} (Position: {index + 1})")

    # Assuming search_iucn_species is a function that takes a species name and returns some result
    result = search_iucn_species(species)

    # Create a DataFrame for the current result
    df_link = pd.DataFrame([result])

    # Append the result to the CSV file (without header after the first write)
    df_link.to_csv("all_download_links.csv", mode='a', index=False, header=not index)

# %% [markdown]
# #### Currently, >1000 species are iterated in the 'search_iucn_species()' function, and those are saved into: 'all_download_links.csv'

# %% [markdown]
# # 4. Download IUCN-reports from the dataframe:

# %%
df_report_download_link = pd.read_csv('all_download_links.csv')
df_report_download_link.columns = ['scientific_name','common_name','download_link']

# deleting rows without download link:
df_report_download_link = df_report_download_link[~df_report_download_link['download_link'].isnull()] # 146 rows have no download_links

df_report_download_link = df_report_download_link.reset_index(drop=True)

# %%
! mkdir iucn_reports

# %%
for link in df_report_download_link['download_link']:
     os.system(f"wget -P iucn_reports {link}")

# %%
! ls iucn_reports | wc -l
# Out:
# 906

# %% [markdown]
# ##### At this point, 906 pdfs have been downloaded

# %% [markdown]
# # 5. Obtaining IUCN-values from the pdfs:

# %%
def extract_data_from_pdf(pdf_path):
    # Open the PDF file
    with pdfplumber.open(pdf_path) as pdf:
        text = ''

        # Loop through all the pages and extract text
        for page in pdf.pages:
            text += page.extract_text()

    # Extract the fields using regular expressions
    try:
        scientific_name = re.search(r'^(Scientific Name:|Taxon Name:)\s*(.*)', text, re.MULTILINE).group(2).strip()
    except:
        scientific_name = ''
    try:
        taxonomy = re.search(r'^Animalia.*', text, re.MULTILINE).group(0).strip()
    except:
        taxonomy = ''
    try:
        red_list_category = re.search(r'Red List Category & Criteria:\s*(.*)', text).group(1).strip()
    except:
        red_list_category = ''
    try:
        date_assessed = re.search(r'Date Assessed:\s*(.*)', text).group(1).strip()
    except:
        date_assessed = ''
    try:
        year_published = re.search(r'Year Published:\s*(.*)', text).group(1).strip()
    except:
        year_published = ''
    try:
        current_population_trend = re.search(r'Current Population Trend:\s*(.*)', text).group(1).strip()
    except:
        current_population_trend = ''
    try:
        systems = re.search(r'Systems:\s*(.*)', text).group(1).strip()
    except:
        systems = ''
    try:
        range_description = re.search(r'Range Description:\s*(.*?)[.]\s', text, re.DOTALL).group(1).strip()
    except:
        range_description = ''
    try:
       habitat_and_ecology = re.search(r'Habitat and Ecology\s*(.*?)[.]\s', text, re.DOTALL).group(1).strip()
    except:
        habitat_and_ecology = ''
    try:
        threats = re.search(r'Threats\s*(.*?)[.]\s', text, re.DOTALL).group(1).strip()
    except:
        threats = ''

    # Return the extracted data as a dictionary
    return {
        "Scientific Name": scientific_name,
        "Taxonomy": taxonomy,
        "Red List Category & Criteria": red_list_category,
        "Date Assessed": date_assessed,
        "Year Published": year_published,
        "Current Population Trend": current_population_trend,
        "Systems": systems,
        "Range Description": range_description,
        "Habitat and Ecology": habitat_and_ecology,
        "Threats": threats
    }

# %%
# ! ls iucn_reports/*.pdf
# Out:
# iucn_reports/102331567.pdf  iucn_reports/182235113.pdf	  iucn_reports/21950199.pdf
# iucn_reports/10331066.pdf   iucn_reports/182235685.pdf	  iucn_reports/21950307.pdf
# iucn_reports/10479343.pdf   iucn_reports/182236363.pdf	  iucn_reports/21950421.pdf
# iucn_reports/111870274.pdf  iucn_reports/182239524.pdf	  iucn_reports/21950491.pdf
# iucn_reports/111871718.pdf  iucn_reports/182239898.pdf	  iucn_reports/21950608.pdf
# iucn_reports/111873502.pdf  iucn_reports/182240168.pdf	  iucn_reports/21950723.pdf
# iucn_reports/111940150.pdf  iucn_reports/182240582.pdf	  iucn_reports/21950802.pdf
# iucn_reports/115063540.pdf  iucn_reports/185202632.pdf	  iucn_reports/21950924.pdf
# iucn_reports/115100163.pdf  iucn_reports/189740044.pdf	  iucn_reports/21950989.pdf
# iucn_reports/115106154.pdf  iucn_reports/190269269.pdf	  iucn_reports/21951066.pdf
# iucn_reports/115106311.pdf  iucn_reports/190319676.pdf	  iucn_reports/21951146.pdf
# iucn_reports/115166757.pdf  iucn_reports/190412426.pdf	  iucn_reports/21951235.pdf
# iucn_reports/115173603.pdf  iucn_reports/190413988.pdf	  iucn_reports/21951309.pdf
# iucn_reports/115173969.pdf  iucn_reports/190414715.pdf	  iucn_reports/21951419.pdf
# iucn_reports/115189017.pdf  iucn_reports/190416507.pdf	  iucn_reports/21951519.pdf
# iucn_reports/115345427.pdf  iucn_reports/190417874.pdf	  iucn_reports/21951638.pdf
# iucn_reports/115559302.pdf  iucn_reports/190424175.pdf	  iucn_reports/21951742.pdf
# iucn_reports/115559557.pdf  iucn_reports/190425583.pdf	  iucn_reports/21951945.pdf
# iucn_reports/115560793.pdf  iucn_reports/190435652.pdf	  iucn_reports/21952015.pdf
# iucn_reports/115561431.pdf  iucn_reports/190450485.pdf	  iucn_reports/21952080.pdf
# iucn_reports/115562060.pdf  iucn_reports/190452803.pdf	  iucn_reports/21952259.pdf
# iucn_reports/115562262.pdf  iucn_reports/190453268.pdf	  iucn_reports/21952423.pdf
# iucn_reports/115562499.pdf  iucn_reports/190455194.pdf	  iucn_reports/21952491.pdf
# iucn_reports/115562696.pdf  iucn_reports/191681999.pdf	  iucn_reports/21952571.pdf
# iucn_reports/115563094.pdf  iucn_reports/191682904.pdf	  iucn_reports/21952658.pdf
# iucn_reports/115564398.pdf  iucn_reports/191684587.pdf	  iucn_reports/21952770.pdf
# iucn_reports/115564580.pdf  iucn_reports/191685783.pdf	  iucn_reports/21952872.pdf
# iucn_reports/115564770.pdf  iucn_reports/191687087.pdf	  iucn_reports/21952954.pdf
# iucn_reports/115565375.pdf  iucn_reports/191688782.pdf	  iucn_reports/21953067.pdf
# iucn_reports/115565566.pdf  iucn_reports/191689524.pdf	  iucn_reports/21953231.pdf
# iucn_reports/115565760.pdf  iucn_reports/191691902.pdf	  iucn_reports/21953329.pdf
# iucn_reports/115566145.pdf  iucn_reports/191692658.pdf	  iucn_reports/21953658.pdf
# iucn_reports/115566334.pdf  iucn_reports/191693399.pdf	  iucn_reports/21953803.pdf
# iucn_reports/115566492.pdf  iucn_reports/191694077.pdf	  iucn_reports/21953894.pdf
# iucn_reports/115566869.pdf  iucn_reports/191697668.pdf	  iucn_reports/21953972.pdf
# iucn_reports/115567059.pdf  iucn_reports/191697842.pdf	  iucn_reports/21954106.pdf
# iucn_reports/115567718.pdf  iucn_reports/191700126.pdf	  iucn_reports/21954274.pdf
# iucn_reports/115570701.pdf  iucn_reports/191700340.pdf	  iucn_reports/21954319.pdf
# iucn_reports/115570887.pdf  iucn_reports/191700629.pdf	  iucn_reports/21954429.pdf
# iucn_reports/115571047.pdf  iucn_reports/191700879.pdf	  iucn_reports/21954573.pdf
# iucn_reports/115571235.pdf  iucn_reports/191701212.pdf	  iucn_reports/21954621.pdf
# iucn_reports/115571806.pdf  iucn_reports/191701453.pdf	  iucn_reports/21954688.pdf
# iucn_reports/115572044.pdf  iucn_reports/191702783.pdf	  iucn_reports/21954751.pdf
# iucn_reports/115572275.pdf  iucn_reports/191703041.pdf	  iucn_reports/21954814.pdf
# iucn_reports/115572495.pdf  iucn_reports/191703935.pdf	  iucn_reports/21954883.pdf
# iucn_reports/115572684.pdf  iucn_reports/191704509.pdf	  iucn_reports/21954955.pdf
# iucn_reports/115572884.pdf  iucn_reports/191704766.pdf	  iucn_reports/21955022.pdf
# iucn_reports/115573104.pdf  iucn_reports/191705043.pdf	  iucn_reports/21955087.pdf
# iucn_reports/115573359.pdf  iucn_reports/191705321.pdf	  iucn_reports/21955167.pdf
# iucn_reports/115573556.pdf  iucn_reports/191706209.pdf	  iucn_reports/21955261.pdf
# iucn_reports/115574178.pdf  iucn_reports/191707236.pdf	  iucn_reports/21955343.pdf
# iucn_reports/115574598.pdf  iucn_reports/191707709.pdf	  iucn_reports/21955455.pdf
# iucn_reports/115574811.pdf  iucn_reports/191708164.pdf	  iucn_reports/21955566.pdf
# iucn_reports/115576640.pdf  iucn_reports/191708662.pdf	  iucn_reports/21955635.pdf
# iucn_reports/115579176.pdf  iucn_reports/192307818.pdf	  iucn_reports/21955754.pdf
# iucn_reports/115579341.pdf  iucn_reports/192315580.pdf	  iucn_reports/21955902.pdf
# iucn_reports/115579719.pdf  iucn_reports/192327291.pdf	  iucn_reports/21955969.pdf
# iucn_reports/115579946.pdf  iucn_reports/192327573.pdf	  iucn_reports/21956108.pdf
# iucn_reports/115581016.pdf  iucn_reports/192399226.pdf	  iucn_reports/21956250.pdf
# iucn_reports/115581154.pdf  iucn_reports/192399613.pdf	  iucn_reports/21956375.pdf
# iucn_reports/115581313.pdf  iucn_reports/192399834.pdf	  iucn_reports/21956516.pdf
# iucn_reports/115581448.pdf  iucn_reports/192400051.pdf	  iucn_reports/21956650.pdf
# iucn_reports/115581600.pdf  iucn_reports/192400226.pdf	  iucn_reports/21956785.pdf
# iucn_reports/115581938.pdf  iucn_reports/192400402.pdf	  iucn_reports/21956889.pdf
# iucn_reports/115582103.pdf  iucn_reports/192400614.pdf	  iucn_reports/21957010.pdf
# iucn_reports/115582253.pdf  iucn_reports/192400781.pdf	  iucn_reports/21957127.pdf
# iucn_reports/115582568.pdf  iucn_reports/192401067.pdf	  iucn_reports/21957219.pdf
# iucn_reports/115582704.pdf  iucn_reports/192446875.pdf	  iucn_reports/21957392.pdf
# iucn_reports/115582831.pdf  iucn_reports/192447067.pdf	  iucn_reports/21957524.pdf
# iucn_reports/115583306.pdf  iucn_reports/192447247.pdf	  iucn_reports/21957669.pdf
# iucn_reports/115583451.pdf  iucn_reports/192447399.pdf	  iucn_reports/21957815.pdf
# iucn_reports/115583605.pdf  iucn_reports/192447536.pdf	  iucn_reports/21957917.pdf
# iucn_reports/115583923.pdf  iucn_reports/192448119.pdf	  iucn_reports/21958021.pdf
# iucn_reports/115584072.pdf  iucn_reports/192451894.pdf	  iucn_reports/21958270.pdf
# iucn_reports/115584379.pdf  iucn_reports/192452042.pdf	  iucn_reports/21958455.pdf
# iucn_reports/115584740.pdf  iucn_reports/192452388.pdf	  iucn_reports/21958627.pdf
# iucn_reports/115585037.pdf  iucn_reports/192452547.pdf	  iucn_reports/21958741.pdf
# iucn_reports/115585199.pdf  iucn_reports/192452656.pdf	  iucn_reports/21958826.pdf
# iucn_reports/115585357.pdf  iucn_reports/192452943.pdf	  iucn_reports/21958924.pdf
# iucn_reports/115585545.pdf  iucn_reports/192453101.pdf	  iucn_reports/21958985.pdf
# iucn_reports/115585671.pdf  iucn_reports/192453653.pdf	  iucn_reports/21959050.pdf
# iucn_reports/115585814.pdf  iucn_reports/192550769.pdf	  iucn_reports/21959203.pdf
# iucn_reports/115585939.pdf  iucn_reports/192551067.pdf	  iucn_reports/21959298.pdf
# iucn_reports/115586218.pdf  iucn_reports/192551696.pdf	  iucn_reports/21959402.pdf
# iucn_reports/115587239.pdf  iucn_reports/192551955.pdf	  iucn_reports/21959531.pdf
# iucn_reports/115587373.pdf  iucn_reports/192552160.pdf	  iucn_reports/21959641.pdf
# iucn_reports/115587527.pdf  iucn_reports/192552331.pdf	  iucn_reports/21959734.pdf
# iucn_reports/115587841.pdf  iucn_reports/192552538.pdf	  iucn_reports/21959798.pdf
# iucn_reports/115587981.pdf  iucn_reports/192552706.pdf	  iucn_reports/21959892.pdf
# iucn_reports/115588141.pdf  iucn_reports/192552857.pdf	  iucn_reports/21959976.pdf
# iucn_reports/115588562.pdf  iucn_reports/192553500.pdf	  iucn_reports/21960093.pdf
# iucn_reports/115588708.pdf  iucn_reports/192553791.pdf	  iucn_reports/21960180.pdf
# iucn_reports/115588845.pdf  iucn_reports/192553958.pdf	  iucn_reports/21960272.pdf
# iucn_reports/116333652.pdf  iucn_reports/192584127.pdf	  iucn_reports/21960570.pdf
# iucn_reports/119877197.pdf  iucn_reports/192584351.pdf	  iucn_reports/21960726.pdf
# iucn_reports/120487417.pdf  iucn_reports/192584742.pdf	  iucn_reports/21960843.pdf
# iucn_reports/120659179.pdf  iucn_reports/192585417.pdf	  iucn_reports/21961179.pdf
# iucn_reports/123796056.pdf  iucn_reports/192585552.pdf	  iucn_reports/21961347.pdf
# iucn_reports/123798768.pdf  iucn_reports/192592138.pdf	  iucn_reports/21961545.pdf
# iucn_reports/12410826.pdf   iucn_reports/192592444.pdf	  iucn_reports/21961626.pdf
# iucn_reports/127530585.pdf  iucn_reports/192592928.pdf	  iucn_reports/21961712.pdf
# iucn_reports/127530628.pdf  iucn_reports/192593226.pdf	  iucn_reports/21961792.pdf
# iucn_reports/128952836.pdf  iucn_reports/192594550.pdf	  iucn_reports/21961873.pdf
# iucn_reports/129038584.pdf  iucn_reports/195347803.pdf	  iucn_reports/21961944.pdf
# iucn_reports/130877829.pdf  iucn_reports/195370322.pdf	  iucn_reports/21962025.pdf
# iucn_reports/136250858.pdf  iucn_reports/195372486.pdf	  iucn_reports/21962231.pdf
# iucn_reports/154209091.pdf  iucn_reports/196007901.pdf	  iucn_reports/21962427.pdf
# iucn_reports/154210757.pdf  iucn_reports/196138291.pdf	  iucn_reports/21962540.pdf
# iucn_reports/160756767.pdf  iucn_reports/196139355.1.pdf  iucn_reports/21962636.pdf
# iucn_reports/16113437.pdf   iucn_reports/196139355.pdf	  iucn_reports/21962719.pdf
# iucn_reports/161178708.pdf  iucn_reports/196325582.pdf	  iucn_reports/21962805.pdf
# iucn_reports/161259430.pdf  iucn_reports/196344962.pdf	  iucn_reports/21962888.pdf
# iucn_reports/162336580.pdf  iucn_reports/196429566.pdf	  iucn_reports/21963019.pdf
# iucn_reports/162369616.pdf  iucn_reports/196465915.pdf	  iucn_reports/21963100.pdf
# iucn_reports/163020759.pdf  iucn_reports/196491153.pdf	  iucn_reports/21963278.pdf
# iucn_reports/163021799.pdf  iucn_reports/196580469.pdf	  iucn_reports/21963339.pdf
# iucn_reports/163021999.pdf  iucn_reports/197306376.pdf	  iucn_reports/21963428.pdf
# iucn_reports/163022293.pdf  iucn_reports/197307208.pdf	  iucn_reports/21963734.pdf
# iucn_reports/163024490.pdf  iucn_reports/197307475.pdf	  iucn_reports/21963834.pdf
# iucn_reports/163312222.pdf  iucn_reports/197307682.pdf	  iucn_reports/21963930.pdf
# iucn_reports/163313088.pdf  iucn_reports/197307942.pdf	  iucn_reports/21964204.pdf
# iucn_reports/163313878.pdf  iucn_reports/197308408.pdf	  iucn_reports/21964353.pdf
# iucn_reports/164046186.pdf  iucn_reports/197308868.pdf	  iucn_reports/21964496.pdf
# iucn_reports/164377626.pdf  iucn_reports/197309091.pdf	  iucn_reports/21964848.pdf
# iucn_reports/166489513.pdf  iucn_reports/197309523.pdf	  iucn_reports/21965004.pdf
# iucn_reports/166495589.pdf  iucn_reports/197309774.pdf	  iucn_reports/21965168.pdf
# iucn_reports/166496257.pdf  iucn_reports/197310136.pdf	  iucn_reports/21965507.pdf
# iucn_reports/166496779.pdf  iucn_reports/197310366.pdf	  iucn_reports/21965649.pdf
# iucn_reports/166498043.pdf  iucn_reports/197310576.pdf	  iucn_reports/21965745.pdf
# iucn_reports/166499137.pdf  iucn_reports/197310863.pdf	  iucn_reports/21965819.pdf
# iucn_reports/166500472.pdf  iucn_reports/197311087.pdf	  iucn_reports/21965953.pdf
# iucn_reports/166524217.pdf  iucn_reports/197311360.pdf	  iucn_reports/21966027.pdf
# iucn_reports/166526155.pdf  iucn_reports/197311536.pdf	  iucn_reports/21966494.pdf
# iucn_reports/166528096.pdf  iucn_reports/197311847.pdf	  iucn_reports/21966655.pdf
# iucn_reports/166528436.pdf  iucn_reports/197312011.pdf	  iucn_reports/21966774.pdf
# iucn_reports/166597159.pdf  iucn_reports/197313066.pdf	  iucn_reports/21966845.pdf
# iucn_reports/166598109.pdf  iucn_reports/197313291.pdf	  iucn_reports/21966942.pdf
# iucn_reports/166598553.pdf  iucn_reports/197313574.pdf	  iucn_reports/21967022.pdf
# iucn_reports/166599765.pdf  iucn_reports/197313900.pdf	  iucn_reports/21967091.pdf
# iucn_reports/166601223.pdf  iucn_reports/197314231.pdf	  iucn_reports/21967189.pdf
# iucn_reports/166604269.pdf  iucn_reports/197321055.pdf	  iucn_reports/21967376.pdf
# iucn_reports/166605018.pdf  iucn_reports/197321380.pdf	  iucn_reports/220971513.pdf
# iucn_reports/166605916.pdf  iucn_reports/197321573.pdf	  iucn_reports/221666136.pdf
# iucn_reports/166606573.pdf  iucn_reports/197321762.pdf	  iucn_reports/22169509.pdf
# iucn_reports/166607033.pdf  iucn_reports/197831931.pdf	  iucn_reports/22169714.pdf
# iucn_reports/166607638.pdf  iucn_reports/198669499.pdf	  iucn_reports/22169828.pdf
# iucn_reports/166609789.pdf  iucn_reports/198687134.pdf	  iucn_reports/22169944.pdf
# iucn_reports/166610679.pdf  iucn_reports/200203263.pdf	  iucn_reports/22170127.pdf
# iucn_reports/166614362.pdf  iucn_reports/200247353.pdf	  iucn_reports/22170338.pdf
# iucn_reports/166615690.pdf  iucn_reports/204397334.pdf	  iucn_reports/22170430.pdf
# iucn_reports/166620835.pdf  iucn_reports/204404464.pdf	  iucn_reports/22170540.pdf
# iucn_reports/167735266.pdf  iucn_reports/205841390.pdf	  iucn_reports/22170648.pdf
# iucn_reports/168568335.pdf  iucn_reports/205875703.pdf	  iucn_reports/22171354.pdf
# iucn_reports/168568698.pdf  iucn_reports/205890248.pdf	  iucn_reports/22171441.pdf
# iucn_reports/169472127.pdf  iucn_reports/205910680.pdf	  iucn_reports/22171555.pdf
# iucn_reports/16971464.pdf   iucn_reports/205911065.pdf	  iucn_reports/22171753.pdf
# iucn_reports/171341769.pdf  iucn_reports/205998680.pdf	  iucn_reports/22172033.pdf
# iucn_reports/171760021.pdf  iucn_reports/206546797.pdf	  iucn_reports/22172283.pdf
# iucn_reports/172269630.pdf  iucn_reports/206546924.pdf	  iucn_reports/22172461.pdf
# iucn_reports/172272430.pdf  iucn_reports/206547044.pdf	  iucn_reports/22172657.pdf
# iucn_reports/172274494.pdf  iucn_reports/206547286.pdf	  iucn_reports/22173132.pdf
# iucn_reports/175862149.pdf  iucn_reports/206547867.pdf	  iucn_reports/22173237.pdf
# iucn_reports/17922442.pdf   iucn_reports/206548613.pdf	  iucn_reports/22173324.pdf
# iucn_reports/17922601.pdf   iucn_reports/206548831.pdf	  iucn_reports/22173467.pdf
# iucn_reports/17923405.pdf   iucn_reports/206549250.pdf	  iucn_reports/22173632.pdf
# iucn_reports/17924752.pdf   iucn_reports/207130315.pdf	  iucn_reports/22173751.pdf
# iucn_reports/17926000.pdf   iucn_reports/210336199.pdf	  iucn_reports/22173952.pdf
# iucn_reports/17929680.pdf   iucn_reports/210337242.pdf	  iucn_reports/22174162.pdf
# iucn_reports/17930113.pdf   iucn_reports/210339606.pdf	  iucn_reports/22174266.pdf
# iucn_reports/17932254.pdf   iucn_reports/210364962.pdf	  iucn_reports/22174358.pdf
# iucn_reports/17934089.pdf   iucn_reports/210368927.pdf	  iucn_reports/22174790.pdf
# iucn_reports/17934268.pdf   iucn_reports/210370097.pdf	  iucn_reports/22174957.pdf
# iucn_reports/17934547.pdf   iucn_reports/210372003.pdf	  iucn_reports/22175055.pdf
# iucn_reports/17935400.pdf   iucn_reports/210377250.pdf	  iucn_reports/22175337.pdf
# iucn_reports/17940474.pdf   iucn_reports/210377447.pdf	  iucn_reports/22175485.pdf
# iucn_reports/17940807.pdf   iucn_reports/210442361.pdf	  iucn_reports/22175821.pdf
# iucn_reports/17941247.pdf   iucn_reports/210442660.pdf	  iucn_reports/22176259.pdf
# iucn_reports/17941672.pdf   iucn_reports/210442893.pdf	  iucn_reports/22176554.pdf
# iucn_reports/17942050.pdf   iucn_reports/210443323.pdf	  iucn_reports/22176668.pdf
# iucn_reports/17942313.pdf   iucn_reports/210443596.pdf	  iucn_reports/22176779.pdf
# iucn_reports/17942651.pdf   iucn_reports/210445926.pdf	  iucn_reports/22177383.pdf
# iucn_reports/17942792.pdf   iucn_reports/210892341.pdf	  iucn_reports/22177663.pdf
# iucn_reports/17942964.pdf   iucn_reports/21282528.pdf	  iucn_reports/22177997.pdf
# iucn_reports/17943210.pdf   iucn_reports/21282601.pdf	  iucn_reports/22178229.pdf
# iucn_reports/17943490.pdf   iucn_reports/21282806.pdf	  iucn_reports/22178294.pdf
# iucn_reports/17943738.pdf   iucn_reports/21283287.pdf	  iucn_reports/22178449.pdf
# iucn_reports/17944213.pdf   iucn_reports/21283546.pdf	  iucn_reports/22178537.pdf
# iucn_reports/17944405.pdf   iucn_reports/21283661.pdf	  iucn_reports/22178618.pdf
# iucn_reports/17944705.pdf   iucn_reports/21284057.pdf	  iucn_reports/22179192.pdf
# iucn_reports/17944855.pdf   iucn_reports/21284422.pdf	  iucn_reports/22179321.pdf
# iucn_reports/17945007.pdf   iucn_reports/21284544.pdf	  iucn_reports/22179598.pdf
# iucn_reports/17945536.pdf   iucn_reports/21284697.pdf	  iucn_reports/22179769.pdf
# iucn_reports/17945814.pdf   iucn_reports/21284863.pdf	  iucn_reports/22179860.pdf
# iucn_reports/17946043.pdf   iucn_reports/21285354.pdf	  iucn_reports/22179949.pdf
# iucn_reports/17946182.pdf   iucn_reports/21285581.pdf	  iucn_reports/22180055.pdf
# iucn_reports/17946672.pdf   iucn_reports/21285759.pdf	  iucn_reports/22180165.pdf
# iucn_reports/17947167.pdf   iucn_reports/21285876.pdf	  iucn_reports/22180239.pdf
# iucn_reports/17947340.pdf   iucn_reports/21286235.pdf	  iucn_reports/22278427.pdf
# iucn_reports/17947990.pdf   iucn_reports/21286316.pdf	  iucn_reports/22278606.pdf
# iucn_reports/17948236.pdf   iucn_reports/21286437.pdf	  iucn_reports/22278758.pdf
# iucn_reports/17948400.pdf   iucn_reports/21286959.pdf	  iucn_reports/22279521.pdf
# iucn_reports/17948833.pdf   iucn_reports/21287143.pdf	  iucn_reports/22279827.pdf
# iucn_reports/17948969.pdf   iucn_reports/21287265.pdf	  iucn_reports/22279973.pdf
# iucn_reports/17949710.pdf   iucn_reports/21287423.pdf	  iucn_reports/22280298.pdf
# iucn_reports/17949875.pdf   iucn_reports/21287768.pdf	  iucn_reports/22280464.pdf
# iucn_reports/17949995.pdf   iucn_reports/21287855.pdf	  iucn_reports/222904443.pdf
# iucn_reports/17950189.pdf   iucn_reports/21288090.pdf	  iucn_reports/222944655.pdf
# iucn_reports/17950422.pdf   iucn_reports/21288271.pdf	  iucn_reports/222944989.pdf
# iucn_reports/17951229.pdf   iucn_reports/21288387.pdf	  iucn_reports/222945240.pdf
# iucn_reports/17951402.pdf   iucn_reports/21288491.pdf	  iucn_reports/223031019.pdf
# iucn_reports/17951596.pdf   iucn_reports/21288575.pdf	  iucn_reports/223433999.pdf
# iucn_reports/17952325.pdf   iucn_reports/21288656.pdf	  iucn_reports/229492631.pdf
# iucn_reports/17952490.pdf   iucn_reports/21288887.pdf	  iucn_reports/229537130.pdf
# iucn_reports/17953082.pdf   iucn_reports/21289173.pdf	  iucn_reports/229775933.pdf
# iucn_reports/17953200.pdf   iucn_reports/21289491.pdf	  iucn_reports/229799507.pdf
# iucn_reports/17953422.pdf   iucn_reports/21289808.pdf	  iucn_reports/43792683.pdf
# iucn_reports/17953573.pdf   iucn_reports/21289898.pdf	  iucn_reports/43793736.pdf
# iucn_reports/17953755.pdf   iucn_reports/21290344.pdf	  iucn_reports/45435551.pdf
# iucn_reports/17953935.pdf   iucn_reports/21290416.pdf	  iucn_reports/45435876.pdf
# iucn_reports/17954139.pdf   iucn_reports/21290631.pdf	  iucn_reports/45436004.pdf
# iucn_reports/17954271.pdf   iucn_reports/21290893.pdf	  iucn_reports/45818198.pdf
# iucn_reports/17954456.pdf   iucn_reports/21291059.pdf	  iucn_reports/46251651.pdf
# iucn_reports/17954836.pdf   iucn_reports/214886892.pdf	  iucn_reports/47437304.pdf
# iucn_reports/17955321.pdf   iucn_reports/215090010.pdf	  iucn_reports/47437534.pdf
# iucn_reports/17955492.pdf   iucn_reports/215090780.pdf	  iucn_reports/47437737.pdf
# iucn_reports/17955753.pdf   iucn_reports/215621115.pdf	  iucn_reports/47437949.pdf
# iucn_reports/17956177.pdf   iucn_reports/217739569.pdf	  iucn_reports/47438745.pdf
# iucn_reports/17956330.pdf   iucn_reports/217754289.pdf	  iucn_reports/47439036.pdf
# iucn_reports/17957592.pdf   iucn_reports/217754712.pdf	  iucn_reports/47439264.pdf
# iucn_reports/17958099.pdf   iucn_reports/217754957.pdf	  iucn_reports/47440020.pdf
# iucn_reports/17958272.pdf   iucn_reports/217755333.pdf	  iucn_reports/47440608.pdf
# iucn_reports/17958623.pdf   iucn_reports/217755480.pdf	  iucn_reports/47440785.pdf
# iucn_reports/17958817.pdf   iucn_reports/217755677.pdf	  iucn_reports/47441122.pdf
# iucn_reports/17958988.pdf   iucn_reports/217755933.pdf	  iucn_reports/47441316.pdf
# iucn_reports/17959133.pdf   iucn_reports/21942936.pdf	  iucn_reports/47441509.pdf
# iucn_reports/17959452.pdf   iucn_reports/21943008.pdf	  iucn_reports/47441708.pdf
# iucn_reports/17959804.pdf   iucn_reports/21943099.pdf	  iucn_reports/47441961.pdf
# iucn_reports/17959977.pdf   iucn_reports/21943259.pdf	  iucn_reports/47442343.pdf
# iucn_reports/17960144.pdf   iucn_reports/21943336.pdf	  iucn_reports/47442649.pdf
# iucn_reports/17960562.pdf   iucn_reports/21943541.pdf	  iucn_reports/47442916.pdf
# iucn_reports/17960997.pdf   iucn_reports/21943616.pdf	  iucn_reports/47443233.pdf
# iucn_reports/17961202.pdf   iucn_reports/21943713.pdf	  iucn_reports/47443455.pdf
# iucn_reports/17961368.pdf   iucn_reports/21943824.pdf	  iucn_reports/47443734.pdf
# iucn_reports/17966495.pdf   iucn_reports/21943904.pdf	  iucn_reports/50043570.pdf
# iucn_reports/17966665.pdf   iucn_reports/21943973.pdf	  iucn_reports/51221937.pdf
# iucn_reports/17967053.pdf   iucn_reports/21944037.pdf	  iucn_reports/51222283.pdf
# iucn_reports/17967253.pdf   iucn_reports/21944128.pdf	  iucn_reports/51343019.pdf
# iucn_reports/17967475.pdf   iucn_reports/21944455.pdf	  iucn_reports/70609585.pdf
# iucn_reports/17967655.pdf   iucn_reports/21944584.pdf	  iucn_reports/70609906.pdf
# iucn_reports/17967873.pdf   iucn_reports/21944685.pdf	  iucn_reports/71510399.pdf
# iucn_reports/17968083.pdf   iucn_reports/21944763.pdf	  iucn_reports/89333796.pdf
# iucn_reports/17968300.pdf   iucn_reports/21944891.pdf	  iucn_reports/92247733.pdf
# iucn_reports/17968556.pdf   iucn_reports/21944952.pdf	  iucn_reports/92248451.pdf
# iucn_reports/17968765.pdf   iucn_reports/21945028.pdf	  iucn_reports/92251260.pdf
# iucn_reports/17968950.pdf   iucn_reports/21945102.pdf	  iucn_reports/92252442.pdf
# iucn_reports/17969392.pdf   iucn_reports/21945246.pdf	  iucn_reports/92345122.pdf
# iucn_reports/17969578.pdf   iucn_reports/21945319.pdf	  iucn_reports/92373680.pdf
# iucn_reports/17971784.pdf   iucn_reports/21945425.pdf	  iucn_reports/92374066.pdf
# iucn_reports/17971831.pdf   iucn_reports/21945496.pdf	  iucn_reports/92384250.pdf
# iucn_reports/17971958.pdf   iucn_reports/21945598.pdf	  iucn_reports/92384429.pdf
# iucn_reports/17972422.pdf   iucn_reports/21945674.pdf	  iucn_reports/92401776.pdf
# iucn_reports/17972778.pdf   iucn_reports/21945813.1.pdf   iucn_reports/92413658.pdf
# iucn_reports/17973006.pdf   iucn_reports/21945813.pdf	  iucn_reports/92629595.pdf
# iucn_reports/17973161.pdf   iucn_reports/21945900.pdf	  iucn_reports/92633245.pdf
# iucn_reports/17973667.pdf   iucn_reports/21945986.pdf	  iucn_reports/92653653.pdf
# iucn_reports/17974148.pdf   iucn_reports/21946093.pdf	  iucn_reports/92656391.pdf
# iucn_reports/17974353.pdf   iucn_reports/21946164.pdf	  iucn_reports/92657454.pdf
# iucn_reports/17974735.pdf   iucn_reports/21946235.pdf	  iucn_reports/92659769.pdf
# iucn_reports/17975106.pdf   iucn_reports/21946313.pdf	  iucn_reports/9356917.pdf
# iucn_reports/17975319.pdf   iucn_reports/21946388.pdf	  iucn_reports/97168578.pdf
# iucn_reports/17975516.pdf   iucn_reports/21946505.pdf	  iucn_reports/97188634.pdf
# iucn_reports/17976302.pdf   iucn_reports/21946586.pdf	  iucn_reports/97188944.pdf
# iucn_reports/17976546.pdf   iucn_reports/21946655.pdf	  iucn_reports/97189172.pdf
# iucn_reports/17976989.pdf   iucn_reports/21946728.pdf	  iucn_reports/97189434.pdf
# iucn_reports/17977202.pdf   iucn_reports/21946847.pdf	  iucn_reports/97189964.pdf
# iucn_reports/17977351.pdf   iucn_reports/21946965.pdf	  iucn_reports/97190215.pdf
# iucn_reports/17977515.pdf   iucn_reports/21947093.pdf	  iucn_reports/97190403.pdf
# iucn_reports/17977659.pdf   iucn_reports/21947190.pdf	  iucn_reports/97190851.pdf
# iucn_reports/17977790.pdf   iucn_reports/21947321.pdf	  iucn_reports/97191108.pdf
# iucn_reports/17977980.pdf   iucn_reports/21947461.pdf	  iucn_reports/97191387.pdf
# iucn_reports/17978130.pdf   iucn_reports/21947794.pdf	  iucn_reports/97191617.pdf
# iucn_reports/17978304.pdf   iucn_reports/21948035.pdf	  iucn_reports/97191808.pdf
# iucn_reports/17978520.pdf   iucn_reports/21948127.pdf	  iucn_reports/97192062.pdf
# iucn_reports/17980668.pdf   iucn_reports/21948233.pdf	  iucn_reports/97200213.pdf
# iucn_reports/17980750.pdf   iucn_reports/21948305.pdf	  iucn_reports/97200480.pdf
# iucn_reports/17985872.pdf   iucn_reports/21948399.pdf	  iucn_reports/97200712.pdf
# iucn_reports/17985924.pdf   iucn_reports/21948474.pdf	  iucn_reports/97200965.pdf
# iucn_reports/17986718.pdf   iucn_reports/21948539.pdf	  iucn_reports/97201228.pdf
# iucn_reports/17986913.pdf   iucn_reports/21948697.pdf	  iucn_reports/97201454.pdf
# iucn_reports/17986963.pdf   iucn_reports/21948773.pdf	  iucn_reports/97201685.pdf
# iucn_reports/17987041.pdf   iucn_reports/21948853.pdf	  iucn_reports/97201954.pdf
# iucn_reports/17988378.pdf   iucn_reports/21948917.pdf	  iucn_reports/97202201.pdf
# iucn_reports/17988500.pdf   iucn_reports/21949068.pdf	  iucn_reports/97202776.pdf
# iucn_reports/17990856.pdf   iucn_reports/21949138.pdf	  iucn_reports/97203050.pdf
# iucn_reports/17990882.pdf   iucn_reports/21949221.pdf	  iucn_reports/97203290.pdf
# iucn_reports/17990934.pdf   iucn_reports/21949291.pdf	  iucn_reports/97203526.pdf
# iucn_reports/17991869.pdf   iucn_reports/21949380.pdf	  iucn_reports/97203842.pdf
# iucn_reports/17991938.pdf   iucn_reports/21949526.pdf	  iucn_reports/97204107.pdf
# iucn_reports/180179376.pdf  iucn_reports/21949654.pdf	  iucn_reports/97206475.pdf
# iucn_reports/180816530.pdf  iucn_reports/21949788.pdf	  iucn_reports/97249081.pdf
# iucn_reports/182121438.pdf  iucn_reports/21949972.pdf	  iucn_reports/9775825.pdf
# iucn_reports/182234286.pdf  iucn_reports/21950078.pdf

# %%
# extract_data_from_pdf('iucn_reports/21946586.pdf')
# extract_data_from_pdf('iucn_reports/166615690.pdf')
# extract_data_from_pdf('iucn_reports/45435876.pdf')
# extract_data_from_pdf('iucn_reports/210442893')
# extract_data_from_pdf('iucn_reports/21286959 ')
# extract_data_from_pdf('iucn_reports/17971958')

# %% [markdown]
# # Needs some cleaning in the dictionary values before saving as csv :)

# %%
def process_all_pdfs_in_directory(directory_path, output_csv):
    # List to hold all the extracted data
    all_data = []

    # Iterate through all files in the directory
    for filename in os.listdir(directory_path):
        if filename.endswith(".pdf"):
            pdf_path = os.path.join(directory_path, filename)
            print(f"Processing {pdf_path}...")
            data = extract_data_from_pdf(pdf_path)
            all_data.append(data)

    # Create a DataFrame from the extracted data
    df = pd.DataFrame(all_data)

    # Save the DataFrame to a CSV file
    df.to_csv(output_csv, index=False)
    print(f"Data saved to {output_csv}")

# %%
# Using the function:

directory_path = 'iucn_reports/'  # Replace with your PDF directory
output_csv = 'iucn_extracted_raw_data.csv'

# Process all PDFs and save the results in a CSV file
process_all_pdfs_in_directory(directory_path, output_csv)
# Out:
# Processing iucn_reports/21964353.pdf...
# Processing iucn_reports/21964496.pdf...
# Processing iucn_reports/21964204.pdf...
# Processing iucn_reports/22180055.pdf...
# Processing iucn_reports/22180165.pdf...
# Processing iucn_reports/22179860.pdf...
# Processing iucn_reports/22179949.pdf...
# Processing iucn_reports/166524217.pdf...
# Processing iucn_reports/22179769.pdf...
# Processing iucn_reports/116333652.pdf...
# Processing iucn_reports/22175821.pdf...
# Processing iucn_reports/197310136.pdf...
# Processing iucn_reports/197321055.pdf...
# Processing iucn_reports/97206475.pdf...
# Processing iucn_reports/22173467.pdf...
# Processing iucn_reports/197310863.pdf...
# Processing iucn_reports/197310366.pdf...
# Processing iucn_reports/22176554.pdf...
# Processing iucn_reports/197310576.pdf...
# Processing iucn_reports/22176668.pdf...
# Processing iucn_reports/22176259.pdf...
# Processing iucn_reports/22175337.pdf...
# Processing iucn_reports/166526155.pdf...
# Processing iucn_reports/197311087.pdf...
# Processing iucn_reports/22177383.pdf...
# Processing iucn_reports/197311360.pdf...
# Processing iucn_reports/22176779.pdf...
# Processing iucn_reports/22173632.pdf...
# Processing iucn_reports/22174790.pdf...
# Processing iucn_reports/22174957.pdf...
# Processing iucn_reports/197309091.pdf...
# Processing iucn_reports/22173952.pdf...
# Processing iucn_reports/22173751.pdf...
# Processing iucn_reports/197308868.pdf...
# Processing iucn_reports/197321573.pdf...
# Processing iucn_reports/22175055.pdf...
# Processing iucn_reports/22174162.pdf...
# Processing iucn_reports/22174358.pdf...
# Processing iucn_reports/22174266.pdf...
# Processing iucn_reports/115106154.pdf...
# Processing iucn_reports/22170648.pdf...
# Processing iucn_reports/197321762.pdf...
# Processing iucn_reports/22171441.pdf...
# Processing iucn_reports/22170430.pdf...
# Processing iucn_reports/197307682.pdf...
# Processing iucn_reports/22170338.pdf...
# Processing iucn_reports/197321380.pdf...
# Processing iucn_reports/115345427.pdf...
# Processing iucn_reports/197307475.pdf...
# Processing iucn_reports/22170540.pdf...
# Processing iucn_reports/22171354.pdf...
# Processing iucn_reports/22172033.pdf...
# Processing iucn_reports/51343019.pdf...
# Processing iucn_reports/22170127.pdf...
# Processing iucn_reports/22171753.pdf...
# Processing iucn_reports/97249081.pdf...
# Processing iucn_reports/22171555.pdf...
# Processing iucn_reports/22177663.pdf...
# Processing iucn_reports/197311536.pdf...
# Processing iucn_reports/22175485.pdf...
# Processing iucn_reports/197311847.pdf...
# Processing iucn_reports/22177997.pdf...
# Processing iucn_reports/197313066.pdf...
# Processing iucn_reports/197312011.pdf...
# Processing iucn_reports/22169509.pdf...
# Processing iucn_reports/22169828.pdf...
# Processing iucn_reports/22169714.pdf...
# Processing iucn_reports/197307208.pdf...
# Processing iucn_reports/22169944.pdf...
# Processing iucn_reports/197306376.pdf...
# Processing iucn_reports/197309774.pdf...
# Processing iucn_reports/22178294.pdf...
# Processing iucn_reports/89333796.pdf...
# Processing iucn_reports/22178229.pdf...
# Processing iucn_reports/22179192.pdf...
# Processing iucn_reports/22179321.pdf...
# Processing iucn_reports/197313574.pdf...
# Processing iucn_reports/115106311.pdf...
# Processing iucn_reports/22178449.pdf...
# Processing iucn_reports/197313291.pdf...
# Processing iucn_reports/22178618.pdf...
# Processing iucn_reports/51221937.pdf...
# Processing iucn_reports/197313900.pdf...
# Processing iucn_reports/197314231.pdf...
# Processing iucn_reports/22178537.pdf...
# Processing iucn_reports/22172461.pdf...
# Processing iucn_reports/197308408.pdf...
# Processing iucn_reports/22173324.pdf...
# Processing iucn_reports/51222283.pdf...
# Processing iucn_reports/22172657.pdf...
# Processing iucn_reports/22173237.pdf...
# Processing iucn_reports/22173132.pdf...
# Processing iucn_reports/197307942.pdf...
# Processing iucn_reports/22172283.pdf...
# Processing iucn_reports/22179598.pdf...
# Processing iucn_reports/197309523.pdf...
# Processing iucn_reports/22180239.pdf...
# Processing iucn_reports/21964848.pdf...
# Processing iucn_reports/21965004.pdf...
# Processing iucn_reports/21945900.pdf...
# Processing iucn_reports/21945813.pdf...
# Processing iucn_reports/21945813.1.pdf...
# Processing iucn_reports/21943336.pdf...
# Processing iucn_reports/21944128.pdf...
# Processing iucn_reports/21946965.pdf...
# Processing iucn_reports/21947461.pdf...
# Processing iucn_reports/21947321.pdf...
# Processing iucn_reports/21946847.pdf...
# Processing iucn_reports/21947093.pdf...
# Processing iucn_reports/21947190.pdf...
# Processing iucn_reports/21945246.pdf...
# Processing iucn_reports/21945102.pdf...
# Processing iucn_reports/21945028.pdf...
# Processing iucn_reports/21943824.pdf...
# Processing iucn_reports/21944584.pdf...
# Processing iucn_reports/21943616.pdf...
# Processing iucn_reports/21943541.pdf...
# Processing iucn_reports/21945319.pdf...
# Processing iucn_reports/21945598.pdf...
# Processing iucn_reports/21945496.pdf...
# Processing iucn_reports/21945674.pdf...
# Processing iucn_reports/21945425.pdf...
# Processing iucn_reports/10331066.pdf...
# Processing iucn_reports/21946505.pdf...
# Processing iucn_reports/21946586.pdf...
# Processing iucn_reports/21946388.pdf...
# Processing iucn_reports/21946235.pdf...
# Processing iucn_reports/21945986.pdf...
# Processing iucn_reports/21946093.pdf...
# Processing iucn_reports/21946728.pdf...
# Processing iucn_reports/21946655.pdf...
# Processing iucn_reports/21946164.pdf...
# Processing iucn_reports/21946313.pdf...
# Processing iucn_reports/21943099.pdf...
# Processing iucn_reports/21943259.pdf...
# Processing iucn_reports/21942936.pdf...
# Processing iucn_reports/21943008.pdf...
# Processing iucn_reports/21944455.pdf...
# Processing iucn_reports/166495589.pdf...
# Processing iucn_reports/21944891.pdf...
# Processing iucn_reports/21944685.pdf...
# Processing iucn_reports/21944952.pdf...
# Processing iucn_reports/21944763.pdf...
# Processing iucn_reports/21943713.pdf...
# Processing iucn_reports/21943973.pdf...
# Processing iucn_reports/21944037.pdf...
# Processing iucn_reports/21943904.pdf...
# Processing iucn_reports/21948127.pdf...
# Processing iucn_reports/21948917.pdf...
# Processing iucn_reports/21948035.pdf...
# Processing iucn_reports/21948539.pdf...
# Processing iucn_reports/21948697.pdf...
# Processing iucn_reports/21948305.pdf...
# Processing iucn_reports/21948233.pdf...
# Processing iucn_reports/21948474.pdf...
# Processing iucn_reports/21948399.pdf...
# Processing iucn_reports/166496257.pdf...
# Processing iucn_reports/21949068.pdf...
# Processing iucn_reports/21949138.pdf...
# Processing iucn_reports/21949221.pdf...
# Processing iucn_reports/21947794.pdf...
# Processing iucn_reports/21948773.pdf...
# Processing iucn_reports/21948853.pdf...
# Processing iucn_reports/21949380.pdf...
# Processing iucn_reports/21949291.pdf...
# Processing iucn_reports/21965168.pdf...
# Processing iucn_reports/21966942.pdf...
# Processing iucn_reports/21966774.pdf...
# Processing iucn_reports/21967022.pdf...
# Processing iucn_reports/21966845.pdf...
# Processing iucn_reports/21966655.pdf...
# Processing iucn_reports/21965745.pdf...
# Processing iucn_reports/21965649.pdf...
# Processing iucn_reports/21965507.pdf...
# Processing iucn_reports/21967091.pdf...
# Processing iucn_reports/115100163.pdf...
# Processing iucn_reports/21966494.pdf...
# Processing iucn_reports/115173603.pdf...
# Processing iucn_reports/21965819.pdf...
# Processing iucn_reports/21965953.pdf...
# Processing iucn_reports/21966027.pdf...
# Processing iucn_reports/115173969.pdf...
# Processing iucn_reports/21967189.pdf...
# Processing iucn_reports/21967376.pdf...
# Processing iucn_reports/21963734.pdf...
# Processing iucn_reports/21955969.pdf...
# Processing iucn_reports/21957127.pdf...
# Processing iucn_reports/21957392.pdf...
# Processing iucn_reports/21957524.pdf...
# Processing iucn_reports/21957669.pdf...
# Processing iucn_reports/21957815.pdf...
# Processing iucn_reports/21956650.pdf...
# Processing iucn_reports/21956785.pdf...
# Processing iucn_reports/21956108.pdf...
# Processing iucn_reports/21957010.pdf...
# Processing iucn_reports/21957219.pdf...
# Processing iucn_reports/21956375.pdf...
# Processing iucn_reports/21956250.pdf...
# Processing iucn_reports/21956889.pdf...
# Processing iucn_reports/21956516.pdf...
# Processing iucn_reports/21954955.pdf...
# Processing iucn_reports/21954883.pdf...
# Processing iucn_reports/21955902.pdf...
# Processing iucn_reports/21955261.pdf...
# Processing iucn_reports/21955087.pdf...
# Processing iucn_reports/21954814.pdf...
# Processing iucn_reports/21954688.pdf...
# Processing iucn_reports/21954751.pdf...
# Processing iucn_reports/21955343.pdf...
# Processing iucn_reports/21954621.pdf...
# Processing iucn_reports/21955754.pdf...
# Processing iucn_reports/21955635.pdf...
# Processing iucn_reports/21955566.pdf...
# Processing iucn_reports/21955022.pdf...
# Processing iucn_reports/21955167.pdf...
# Processing iucn_reports/21955455.pdf...
# Processing iucn_reports/21958627.pdf...
# Processing iucn_reports/21958826.pdf...
# Processing iucn_reports/21958741.pdf...
# Processing iucn_reports/21958270.pdf...
# Processing iucn_reports/21958455.pdf...
# Processing iucn_reports/21952571.pdf...
# Processing iucn_reports/21952491.pdf...
# Processing iucn_reports/21952259.pdf...
# Processing iucn_reports/21952423.pdf...
# Processing iucn_reports/21952872.pdf...
# Processing iucn_reports/21952770.pdf...
# Processing iucn_reports/21954573.pdf...
# Processing iucn_reports/21954319.pdf...
# Processing iucn_reports/21954429.pdf...
# Processing iucn_reports/21954274.pdf...
# Processing iucn_reports/21953972.pdf...
# Processing iucn_reports/21952954.pdf...
# Processing iucn_reports/21954106.pdf...
# Processing iucn_reports/21953658.pdf...
# Processing iucn_reports/21953803.pdf...
# Processing iucn_reports/128952836.pdf...
# Processing iucn_reports/21953231.pdf...
# Processing iucn_reports/21953067.pdf...
# Processing iucn_reports/21953894.pdf...
# Processing iucn_reports/21953329.pdf...
# Processing iucn_reports/21957917.pdf...
# Processing iucn_reports/21958021.pdf...
# Processing iucn_reports/21952658.pdf...
# Processing iucn_reports/71510399.pdf...
# Processing iucn_reports/21961179.pdf...
# Processing iucn_reports/21961347.pdf...
# Processing iucn_reports/21960843.pdf...
# Processing iucn_reports/115063540.pdf...
# Processing iucn_reports/21961545.pdf...
# Processing iucn_reports/21960726.pdf...
# Processing iucn_reports/166498043.pdf...
# Processing iucn_reports/21960570.pdf...
# Processing iucn_reports/166499137.pdf...
# Processing iucn_reports/21963834.pdf...
# Processing iucn_reports/21963930.pdf...
# Processing iucn_reports/21960272.pdf...
# Processing iucn_reports/21959892.pdf...
# Processing iucn_reports/21960180.pdf...
# Processing iucn_reports/21960093.pdf...
# Processing iucn_reports/21959976.pdf...
# Processing iucn_reports/21959298.pdf...
# Processing iucn_reports/21959641.pdf...
# Processing iucn_reports/21959734.pdf...
# Processing iucn_reports/21959798.pdf...
# Processing iucn_reports/21959531.pdf...
# Processing iucn_reports/21959402.pdf...
# Processing iucn_reports/21962427.pdf...
# Processing iucn_reports/166500472.pdf...
# Processing iucn_reports/21963100.pdf...
# Processing iucn_reports/21963019.pdf...
# Processing iucn_reports/21961626.pdf...
# Processing iucn_reports/21961944.pdf...
# Processing iucn_reports/21962025.pdf...
# Processing iucn_reports/21961873.pdf...
# Processing iucn_reports/21962231.pdf...
# Processing iucn_reports/21961712.pdf...
# Processing iucn_reports/21961792.pdf...
# Processing iucn_reports/21962540.pdf...
# Processing iucn_reports/21962719.pdf...
# Processing iucn_reports/21962636.pdf...
# Processing iucn_reports/21962888.pdf...
# Processing iucn_reports/21962805.pdf...
# Processing iucn_reports/21958924.pdf...
# Processing iucn_reports/9775825.pdf...
# Processing iucn_reports/21963339.pdf...
# Processing iucn_reports/21963278.pdf...
# Processing iucn_reports/21963428.pdf...
# Processing iucn_reports/21949526.pdf...
# Processing iucn_reports/21949654.pdf...
# Processing iucn_reports/21951742.pdf...
# Processing iucn_reports/21950608.pdf...
# Processing iucn_reports/21950989.pdf...
# Processing iucn_reports/21951309.pdf...
# Processing iucn_reports/21950491.pdf...
# Processing iucn_reports/21951419.pdf...
# Processing iucn_reports/21951146.pdf...
# Processing iucn_reports/21950802.pdf...
# Processing iucn_reports/21951638.pdf...
# Processing iucn_reports/21951519.pdf...
# Processing iucn_reports/21951066.pdf...
# Processing iucn_reports/21950924.pdf...
# Processing iucn_reports/21951235.pdf...
# Processing iucn_reports/21950723.pdf...
# Processing iucn_reports/21950199.pdf...
# Processing iucn_reports/21950307.pdf...
# Processing iucn_reports/21949972.pdf...
# Processing iucn_reports/21949788.pdf...
# Processing iucn_reports/21950078.pdf...
# Processing iucn_reports/21951945.pdf...
# Processing iucn_reports/21952015.pdf...
# Processing iucn_reports/21952080.pdf...
# Processing iucn_reports/21950421.pdf...
# Processing iucn_reports/166496779.pdf...
# Processing iucn_reports/21959050.pdf...
# Processing iucn_reports/21959203.pdf...
# Processing iucn_reports/21958985.pdf...
# Processing iucn_reports/47439036.pdf...
# Processing iucn_reports/47439264.pdf...
# Processing iucn_reports/119877197.pdf...
# Processing iucn_reports/47438745.pdf...
# Processing iucn_reports/47441708.pdf...
# Processing iucn_reports/47443734.pdf...
# Processing iucn_reports/47437304.pdf...
# Processing iucn_reports/47437534.pdf...
# Processing iucn_reports/47437737.pdf...
# Processing iucn_reports/47437949.pdf...
# Processing iucn_reports/47442343.pdf...
# Processing iucn_reports/47443233.pdf...
# Processing iucn_reports/47443455.pdf...
# Processing iucn_reports/47440608.pdf...
# Processing iucn_reports/47440785.pdf...
# Processing iucn_reports/47441122.pdf...
# Processing iucn_reports/47441316.pdf...
# Processing iucn_reports/47441509.pdf...
# Processing iucn_reports/210445926.pdf...
# Processing iucn_reports/210442361.pdf...
# Processing iucn_reports/210442660.pdf...
# Processing iucn_reports/210442893.pdf...
# Processing iucn_reports/210443323.pdf...
# Processing iucn_reports/210443596.pdf...
# Processing iucn_reports/47440020.pdf...
# Processing iucn_reports/47441961.pdf...
# Processing iucn_reports/47442649.pdf...
# Processing iucn_reports/47442916.pdf...
# Processing iucn_reports/21288656.pdf...
# Processing iucn_reports/21290344.pdf...
# Processing iucn_reports/21288575.pdf...
# Processing iucn_reports/21288491.pdf...
# Processing iucn_reports/21289808.pdf...
# Processing iucn_reports/21289491.pdf...
# Processing iucn_reports/21291059.pdf...
# Processing iucn_reports/21290631.pdf...
# Processing iucn_reports/45435876.pdf...
# Processing iucn_reports/45436004.pdf...
# Processing iucn_reports/45435551.pdf...
# Processing iucn_reports/21290893.pdf...
# Processing iucn_reports/21287265.pdf...
# Processing iucn_reports/166489513.pdf...
# Processing iucn_reports/21286959.pdf...
# Processing iucn_reports/21287423.pdf...
# Processing iucn_reports/21284863.pdf...
# Processing iucn_reports/21286316.pdf...
# Processing iucn_reports/21284544.pdf...
# Processing iucn_reports/21284697.pdf...
# Processing iucn_reports/21284057.pdf...
# Processing iucn_reports/21284422.pdf...
# Processing iucn_reports/21288887.pdf...
# Processing iucn_reports/21283546.pdf...
# Processing iucn_reports/21285354.pdf...
# Processing iucn_reports/21289173.pdf...
# Processing iucn_reports/21285581.pdf...
# Processing iucn_reports/21285759.pdf...
# Processing iucn_reports/21288387.pdf...
# Processing iucn_reports/21288271.pdf...
# Processing iucn_reports/21287855.pdf...
# Processing iucn_reports/21289898.pdf...
# Processing iucn_reports/21290416.pdf...
# Processing iucn_reports/21287143.pdf...
# Processing iucn_reports/21286235.pdf...
# Processing iucn_reports/21283661.pdf...
# Processing iucn_reports/111940150.pdf...
# Processing iucn_reports/21287768.pdf...
# Processing iucn_reports/97203526.pdf...
# Processing iucn_reports/97188944.pdf...
# Processing iucn_reports/97189964.pdf...
# Processing iucn_reports/97190403.pdf...
# Processing iucn_reports/97190851.pdf...
# Processing iucn_reports/97191108.pdf...
# Processing iucn_reports/97191387.pdf...
# Processing iucn_reports/97191617.pdf...
# Processing iucn_reports/97190215.pdf...
# Processing iucn_reports/97191808.pdf...
# Processing iucn_reports/97192062.pdf...
# Processing iucn_reports/21282528.pdf...
# Processing iucn_reports/97200213.pdf...
# Processing iucn_reports/97200480.pdf...
# Processing iucn_reports/97200712.pdf...
# Processing iucn_reports/97200965.pdf...
# Processing iucn_reports/97201228.pdf...
# Processing iucn_reports/97201454.pdf...
# Processing iucn_reports/97201685.pdf...
# Processing iucn_reports/97201954.pdf...
# Processing iucn_reports/97202201.pdf...
# Processing iucn_reports/97202776.pdf...
# Processing iucn_reports/97203050.pdf...
# Processing iucn_reports/97203290.pdf...
# Processing iucn_reports/97188634.pdf...
# Processing iucn_reports/97189172.pdf...
# Processing iucn_reports/97189434.pdf...
# Processing iucn_reports/97203842.pdf...
# Processing iucn_reports/97204107.pdf...
# Processing iucn_reports/21286437.pdf...
# Processing iucn_reports/45818198.pdf...
# Processing iucn_reports/223031019.pdf...
# Processing iucn_reports/204404464.pdf...
# Processing iucn_reports/21282806.pdf...
# Processing iucn_reports/21282601.pdf...
# Processing iucn_reports/21288090.pdf...
# Processing iucn_reports/21283287.pdf...
# Processing iucn_reports/21285876.pdf...
# Processing iucn_reports/160756767.pdf...
# Processing iucn_reports/43792683.pdf...
# Processing iucn_reports/43793736.pdf...
# Processing iucn_reports/9356917.pdf...
# Processing iucn_reports/97168578.pdf...
# Processing iucn_reports/12410826.pdf...
# Processing iucn_reports/10479343.pdf...
# Processing iucn_reports/229799507.pdf...
# Processing iucn_reports/22278758.pdf...
# Processing iucn_reports/22278427.pdf...
# Processing iucn_reports/22278606.pdf...
# Processing iucn_reports/229775933.pdf...
# Processing iucn_reports/111870274.pdf...
# Processing iucn_reports/111873502.pdf...
# Processing iucn_reports/22280298.pdf...
# Processing iucn_reports/130877829.pdf...
# Processing iucn_reports/166528436.pdf...
# Processing iucn_reports/123796056.pdf...
# Processing iucn_reports/115189017.pdf...
# Processing iucn_reports/166528096.pdf...
# Processing iucn_reports/22280464.pdf...
# Processing iucn_reports/123798768.pdf...
# Processing iucn_reports/229537130.pdf...
# Processing iucn_reports/22279521.pdf...
# Processing iucn_reports/115166757.pdf...
# Processing iucn_reports/22279973.pdf...
# Processing iucn_reports/111871718.pdf...
# Processing iucn_reports/22279827.pdf...
# Processing iucn_reports/229492631.pdf...
# Processing iucn_reports/166606573.pdf...
# Processing iucn_reports/92345122.pdf...
# Processing iucn_reports/161178708.pdf...
# Processing iucn_reports/154209091.pdf...
# Processing iucn_reports/17947340.pdf...
# Processing iucn_reports/92374066.pdf...
# Processing iucn_reports/166614362.pdf...
# Processing iucn_reports/92413658.pdf...
# Processing iucn_reports/92384250.pdf...
# Processing iucn_reports/17946182.pdf...
# Processing iucn_reports/17946043.pdf...
# Processing iucn_reports/166615690.pdf...
# Processing iucn_reports/92401776.pdf...
# Processing iucn_reports/92373680.pdf...
# Processing iucn_reports/196007901.pdf...
# Processing iucn_reports/17946672.pdf...
# Processing iucn_reports/17947167.pdf...
# Processing iucn_reports/222904443.pdf...
# Processing iucn_reports/17945536.pdf...
# Processing iucn_reports/92384429.pdf...
# Processing iucn_reports/17945814.pdf...
# Processing iucn_reports/166601223.pdf...
# Processing iucn_reports/214886892.pdf...
# Processing iucn_reports/17957592.pdf...
# Processing iucn_reports/205910680.pdf...
# Processing iucn_reports/210337242.pdf...
# Processing iucn_reports/205998680.pdf...
# Processing iucn_reports/17958099.pdf...
# Processing iucn_reports/17958272.pdf...
# Processing iucn_reports/92252442.pdf...
# Processing iucn_reports/217739569.pdf...
# Processing iucn_reports/164377626.pdf...
# Processing iucn_reports/17953573.pdf...
# Processing iucn_reports/166605916.pdf...
# Processing iucn_reports/167735266.pdf...
# Processing iucn_reports/92248451.pdf...
# Processing iucn_reports/17956177.pdf...
# Processing iucn_reports/17956330.pdf...
# Processing iucn_reports/92247733.pdf...
# Processing iucn_reports/17955753.pdf...
# Processing iucn_reports/154210757.pdf...
# Processing iucn_reports/166607033.pdf...
# Processing iucn_reports/166607638.pdf...
# Processing iucn_reports/185202632.pdf...
# Processing iucn_reports/17950189.pdf...
# Processing iucn_reports/17985924.pdf...
# Processing iucn_reports/17949875.pdf...
# Processing iucn_reports/221666136.pdf...
# Processing iucn_reports/195347803.pdf...
# Processing iucn_reports/17948969.pdf...
# Processing iucn_reports/217754289.pdf...
# Processing iucn_reports/205890248.pdf...
# Processing iucn_reports/197831931.pdf...
# Processing iucn_reports/17948833.pdf...
# Processing iucn_reports/223433999.pdf...
# Processing iucn_reports/17950422.pdf...
# Processing iucn_reports/17948400.pdf...
# Processing iucn_reports/17985872.pdf...
# Processing iucn_reports/17949995.pdf...
# Processing iucn_reports/17951596.pdf...
# Processing iucn_reports/17949710.pdf...
# Processing iucn_reports/17951402.pdf...
# Processing iucn_reports/17951229.pdf...
# Processing iucn_reports/50043570.pdf...
# Processing iucn_reports/17948236.pdf...
# Processing iucn_reports/17947990.pdf...
# Processing iucn_reports/17952490.pdf...
# Processing iucn_reports/17952325.pdf...
# Processing iucn_reports/17953200.pdf...
# Processing iucn_reports/92251260.pdf...
# Processing iucn_reports/17953082.pdf...
# Processing iucn_reports/190319676.pdf...
# Processing iucn_reports/190269269.pdf...
# Processing iucn_reports/168568698.pdf...
# Processing iucn_reports/17961368.pdf...
# Processing iucn_reports/217754712.pdf...
# Processing iucn_reports/17945007.pdf...
# Processing iucn_reports/17944705.pdf...
# Processing iucn_reports/17944855.pdf...
# Processing iucn_reports/17944405.pdf...
# Processing iucn_reports/169472127.pdf...
# Processing iucn_reports/161259430.pdf...
# Processing iucn_reports/210339606.pdf...
# Processing iucn_reports/92656391.pdf...
# Processing iucn_reports/92659769.pdf...
# Processing iucn_reports/92629595.pdf...
# Processing iucn_reports/168568335.pdf...
# Processing iucn_reports/166605018.pdf...
# Processing iucn_reports/166598553.pdf...
# Processing iucn_reports/166604269.pdf...
# Processing iucn_reports/92653653.pdf...
# Processing iucn_reports/92633245.pdf...
# Processing iucn_reports/166599765.pdf...
# Processing iucn_reports/92657454.pdf...
# Processing iucn_reports/171760021.pdf...
# Processing iucn_reports/166598109.pdf...
# Processing iucn_reports/166620835.pdf...
# Processing iucn_reports/166610679.pdf...
# Processing iucn_reports/195372486.pdf...
# Processing iucn_reports/206547286.pdf...
# Processing iucn_reports/200247353.pdf...
# Processing iucn_reports/17955321.pdf...
# Processing iucn_reports/210370097.pdf...
# Processing iucn_reports/215090780.pdf...
# Processing iucn_reports/17954836.pdf...
# Processing iucn_reports/195370322.pdf...
# Processing iucn_reports/17954271.pdf...
# Processing iucn_reports/17986718.pdf...
# Processing iucn_reports/17955492.pdf...
# Processing iucn_reports/205841390.pdf...
# Processing iucn_reports/17954456.pdf...
# Processing iucn_reports/205875703.pdf...
# Processing iucn_reports/17953935.pdf...
# Processing iucn_reports/17987041.pdf...
# Processing iucn_reports/17953755.pdf...
# Processing iucn_reports/17986963.pdf...
# Processing iucn_reports/17986913.pdf...
# Processing iucn_reports/17954139.pdf...
# Processing iucn_reports/17941672.pdf...
# Processing iucn_reports/17941247.pdf...
# Processing iucn_reports/196138291.pdf...
# Processing iucn_reports/17944213.pdf...
# Processing iucn_reports/17943738.pdf...
# Processing iucn_reports/215621115.pdf...
# Processing iucn_reports/196491153.pdf...
# Processing iucn_reports/17943490.pdf...
# Processing iucn_reports/17943210.pdf...
# Processing iucn_reports/17942050.pdf...
# Processing iucn_reports/17942651.pdf...
# Processing iucn_reports/17942313.pdf...
# Processing iucn_reports/17958623.pdf...
# Processing iucn_reports/17942964.pdf...
# Processing iucn_reports/17942792.pdf...
# Processing iucn_reports/17959452.pdf...
# Processing iucn_reports/17953422.pdf...
# Processing iucn_reports/17988500.pdf...
# Processing iucn_reports/17960144.pdf...
# Processing iucn_reports/204397334.pdf...
# Processing iucn_reports/17959977.pdf...
# Processing iucn_reports/17958988.pdf...
# Processing iucn_reports/196139355.pdf...
# Processing iucn_reports/17958817.pdf...
# Processing iucn_reports/17960997.pdf...
# Processing iucn_reports/217754957.pdf...
# Processing iucn_reports/196139355.1.pdf...
# Processing iucn_reports/17959133.pdf...
# Processing iucn_reports/17988378.pdf...
# Processing iucn_reports/210372003.pdf...
# Processing iucn_reports/196325582.pdf...
# Processing iucn_reports/17960562.pdf...
# Processing iucn_reports/175862149.pdf...
# Processing iucn_reports/196580469.pdf...
# Processing iucn_reports/17959804.pdf...
# Processing iucn_reports/196344962.pdf...
# Processing iucn_reports/205911065.pdf...
# Processing iucn_reports/17961202.pdf...
# Processing iucn_reports/115576640.pdf...
# Processing iucn_reports/136250858.pdf...
# Processing iucn_reports/102331567.pdf...
# Processing iucn_reports/129038584.pdf...
# Processing iucn_reports/17968083.pdf...
# Processing iucn_reports/17968300.pdf...
# Processing iucn_reports/166597159.pdf...
# Processing iucn_reports/17990882.pdf...
# Processing iucn_reports/17967655.pdf...
# Processing iucn_reports/17967053.pdf...
# Processing iucn_reports/17990856.pdf...
# Processing iucn_reports/17967475.pdf...
# Processing iucn_reports/17967253.pdf...
# Processing iucn_reports/17966495.pdf...
# Processing iucn_reports/17990934.pdf...
# Processing iucn_reports/17966665.pdf...
# Processing iucn_reports/120659179.pdf...
# Processing iucn_reports/17968556.pdf...
# Processing iucn_reports/17968950.pdf...
# Processing iucn_reports/17969392.pdf...
# Processing iucn_reports/180816530.pdf...
# Processing iucn_reports/17969578.pdf...
# Processing iucn_reports/17968765.pdf...
# Processing iucn_reports/17967873.pdf...
# Processing iucn_reports/190450485.pdf...
# Processing iucn_reports/17923405.pdf...
# Processing iucn_reports/190452803.pdf...
# Processing iucn_reports/190453268.pdf...
# Processing iucn_reports/17922601.pdf...
# Processing iucn_reports/164046186.pdf...
# Processing iucn_reports/190455194.pdf...
# Processing iucn_reports/191681999.pdf...
# Processing iucn_reports/191682904.pdf...
# Processing iucn_reports/17922442.pdf...
# Processing iucn_reports/190413988.pdf...
# Processing iucn_reports/190412426.pdf...
# Processing iucn_reports/190414715.pdf...
# Processing iucn_reports/190416507.pdf...
# Processing iucn_reports/190417874.pdf...
# Processing iucn_reports/198669499.pdf...
# Processing iucn_reports/190424175.pdf...
# Processing iucn_reports/190425583.pdf...
# Processing iucn_reports/17926000.pdf...
# Processing iucn_reports/17924752.pdf...
# Processing iucn_reports/198687134.pdf...
# Processing iucn_reports/190435652.pdf...
# Processing iucn_reports/191684587.pdf...
# Processing iucn_reports/191685783.pdf...
# Processing iucn_reports/191687087.pdf...
# Processing iucn_reports/191688782.pdf...
# Processing iucn_reports/17929680.pdf...
# Processing iucn_reports/191689524.pdf...
# Processing iucn_reports/191691902.pdf...
# Processing iucn_reports/191692658.pdf...
# Processing iucn_reports/191693399.pdf...
# Processing iucn_reports/192307818.pdf...
# Processing iucn_reports/191700340.pdf...
# Processing iucn_reports/191700629.pdf...
# Processing iucn_reports/191700879.pdf...
# Processing iucn_reports/191701212.pdf...
# Processing iucn_reports/191705043.pdf...
# Processing iucn_reports/191701453.pdf...
# Processing iucn_reports/191705321.pdf...
# Processing iucn_reports/191707236.pdf...
# Processing iucn_reports/200203263.pdf...
# Processing iucn_reports/206547044.pdf...
# Processing iucn_reports/192327573.pdf...
# Processing iucn_reports/17935400.pdf...
# Processing iucn_reports/192327291.pdf...
# Processing iucn_reports/192400051.pdf...
# Processing iucn_reports/192399613.pdf...
# Processing iucn_reports/192399226.pdf...
# Processing iucn_reports/192400402.pdf...
# Processing iucn_reports/192399834.pdf...
# Processing iucn_reports/191706209.pdf...
# Processing iucn_reports/17934268.pdf...
# Processing iucn_reports/17934089.pdf...
# Processing iucn_reports/206547867.pdf...
# Processing iucn_reports/192400226.pdf...
# Processing iucn_reports/192400781.pdf...
# Processing iucn_reports/172269630.pdf...
# Processing iucn_reports/17934547.pdf...
# Processing iucn_reports/192401067.pdf...
# Processing iucn_reports/192400614.pdf...
# Processing iucn_reports/222945240.pdf...
# Processing iucn_reports/192551696.pdf...
# Processing iucn_reports/192315580.pdf...
# Processing iucn_reports/17980668.pdf...
# Processing iucn_reports/192551955.pdf...
# Processing iucn_reports/17980750.pdf...
# Processing iucn_reports/192553500.pdf...
# Processing iucn_reports/192552160.pdf...
# Processing iucn_reports/192552331.pdf...
# Processing iucn_reports/192550769.pdf...
# Processing iucn_reports/192552857.pdf...
# Processing iucn_reports/192552538.pdf...
# Processing iucn_reports/192552706.pdf...
# Processing iucn_reports/192553958.pdf...
# Processing iucn_reports/17932254.pdf...
# Processing iucn_reports/192551067.pdf...
# Processing iucn_reports/17930113.pdf...
# Processing iucn_reports/192553791.pdf...
# Processing iucn_reports/191703935.pdf...
# Processing iucn_reports/191708164.pdf...
# Processing iucn_reports/191704766.pdf...
# Processing iucn_reports/191708662.pdf...
# Processing iucn_reports/192594550.pdf...
# Processing iucn_reports/222944655.pdf...
# Processing iucn_reports/192592928.pdf...
# Processing iucn_reports/192593226.pdf...
# Processing iucn_reports/210336199.pdf...
# Processing iucn_reports/192592444.pdf...
# Processing iucn_reports/192592138.pdf...
# Processing iucn_reports/192584127.pdf...
# Processing iucn_reports/192585552.pdf...
# Processing iucn_reports/192585417.pdf...
# Processing iucn_reports/17940807.pdf...
# Processing iucn_reports/192584742.pdf...
# Processing iucn_reports/192584351.pdf...
# Processing iucn_reports/17940474.pdf...
# Processing iucn_reports/191703041.pdf...
# Processing iucn_reports/17972422.pdf...
# Processing iucn_reports/17975106.pdf...
# Processing iucn_reports/17973667.pdf...
# Processing iucn_reports/191700126.pdf...
# Processing iucn_reports/217755333.pdf...
# Processing iucn_reports/217755480.pdf...
# Processing iucn_reports/217755677.pdf...
# Processing iucn_reports/217755933.pdf...
# Processing iucn_reports/210892341.pdf...
# Processing iucn_reports/192452943.pdf...
# Processing iucn_reports/17974353.pdf...
# Processing iucn_reports/17973161.pdf...
# Processing iucn_reports/17974148.pdf...
# Processing iucn_reports/17973006.pdf...
# Processing iucn_reports/192453101.pdf...
# Processing iucn_reports/206548613.pdf...
# Processing iucn_reports/192453653.pdf...
# Processing iucn_reports/192452388.pdf...
# Processing iucn_reports/192451894.pdf...
# Processing iucn_reports/172272430.pdf...
# Processing iucn_reports/166609789.pdf...
# Processing iucn_reports/206549250.pdf...
# Processing iucn_reports/17972778.pdf...
# Processing iucn_reports/192452656.pdf...
# Processing iucn_reports/17975319.pdf...
# Processing iucn_reports/17975516.pdf...
# Processing iucn_reports/17974735.pdf...
# Processing iucn_reports/192452042.pdf...
# Processing iucn_reports/172274494.pdf...
# Processing iucn_reports/192452547.pdf...
# Processing iucn_reports/127530628.pdf...
# Processing iucn_reports/127530585.pdf...
# Processing iucn_reports/222944989.pdf...
# Processing iucn_reports/17976302.pdf...
# Processing iucn_reports/191694077.pdf...
# Processing iucn_reports/210377447.pdf...
# Processing iucn_reports/191697668.pdf...
# Processing iucn_reports/191697842.pdf...
# Processing iucn_reports/210377250.pdf...
# Processing iucn_reports/206546924.pdf...
# Processing iucn_reports/206546797.pdf...
# Processing iucn_reports/191702783.pdf...
# Processing iucn_reports/17976546.pdf...
# Processing iucn_reports/191707709.pdf...
# Processing iucn_reports/191704509.pdf...
# Processing iucn_reports/17971831.pdf...
# Processing iucn_reports/192447067.pdf...
# Processing iucn_reports/192447536.pdf...
# Processing iucn_reports/17991938.pdf...
# Processing iucn_reports/206548831.pdf...
# Processing iucn_reports/192447399.pdf...
# Processing iucn_reports/192448119.pdf...
# Processing iucn_reports/70609906.pdf...
# Processing iucn_reports/192446875.pdf...
# Processing iucn_reports/17971958.pdf...
# Processing iucn_reports/70609585.pdf...
# Processing iucn_reports/192447247.pdf...
# Processing iucn_reports/17991869.pdf...
# Processing iucn_reports/17978520.pdf...
# Processing iucn_reports/17976989.pdf...
# Processing iucn_reports/17977790.pdf...
# Processing iucn_reports/162369616.pdf...
# Processing iucn_reports/17978130.pdf...
# Processing iucn_reports/171341769.pdf...
# Processing iucn_reports/17977515.pdf...
# Processing iucn_reports/17977980.pdf...
# Processing iucn_reports/17977351.pdf...
# Processing iucn_reports/162336580.pdf...
# Processing iucn_reports/220971513.pdf...
# Processing iucn_reports/17978304.pdf...
# Processing iucn_reports/17977202.pdf...
# Processing iucn_reports/17977659.pdf...
# Processing iucn_reports/115560793.pdf...
# Processing iucn_reports/115559302.pdf...
# Processing iucn_reports/163021799.pdf...
# Processing iucn_reports/115581154.pdf...
# Processing iucn_reports/163021999.pdf...
# Processing iucn_reports/163022293.pdf...
# Processing iucn_reports/115588708.pdf...
# Processing iucn_reports/115588562.pdf...
# Processing iucn_reports/163020759.pdf...
# Processing iucn_reports/115579719.pdf...
# Processing iucn_reports/163312222.pdf...
# Processing iucn_reports/115587373.pdf...
# Processing iucn_reports/215090010.pdf...
# Processing iucn_reports/115583451.pdf...
# Processing iucn_reports/182240168.pdf...
# Processing iucn_reports/120487417.pdf...
# Processing iucn_reports/163313088.pdf...
# Processing iucn_reports/16971464.pdf...
# Processing iucn_reports/115583923.pdf...
# Processing iucn_reports/180179376.pdf...
# Processing iucn_reports/196429566.pdf...
# Processing iucn_reports/210364962.pdf...
# Processing iucn_reports/115587527.pdf...
# Processing iucn_reports/115581016.pdf...
# Processing iucn_reports/163313878.pdf...
# Processing iucn_reports/115587239.pdf...
# Processing iucn_reports/46251651.pdf...
# Processing iucn_reports/182239898.pdf...
# Processing iucn_reports/16113437.pdf...
# Processing iucn_reports/115574811.pdf...
# Processing iucn_reports/115588845.pdf...
# Processing iucn_reports/115579341.pdf...
# Processing iucn_reports/115585545.pdf...
# Processing iucn_reports/163024490.pdf...
# Processing iucn_reports/115579176.pdf...
# Processing iucn_reports/115567718.pdf...
# Processing iucn_reports/182240582.pdf...
# Processing iucn_reports/115571235.pdf...
# Processing iucn_reports/115570701.pdf...
# Processing iucn_reports/115571047.pdf...
# Processing iucn_reports/115570887.pdf...
# Processing iucn_reports/115585814.pdf...
# Processing iucn_reports/115582253.pdf...
# Processing iucn_reports/115559557.pdf...
# Processing iucn_reports/115582568.pdf...
# Processing iucn_reports/115588141.pdf...
# Processing iucn_reports/182234286.pdf...
# Processing iucn_reports/115581938.pdf...
# Processing iucn_reports/115579946.pdf...
# Processing iucn_reports/115565566.pdf...
# Processing iucn_reports/115573359.pdf...
# Processing iucn_reports/115572275.pdf...
# Processing iucn_reports/115572495.pdf...
# Processing iucn_reports/115572684.pdf...
# Processing iucn_reports/115572884.pdf...
# Processing iucn_reports/115573104.pdf...
# Processing iucn_reports/115573556.pdf...
# Processing iucn_reports/115571806.pdf...
# Processing iucn_reports/115572044.pdf...
# Processing iucn_reports/182121438.pdf...
# Processing iucn_reports/115562060.pdf...
# Processing iucn_reports/115562262.pdf...
# Processing iucn_reports/182239524.pdf...
# Processing iucn_reports/115563094.pdf...
# Processing iucn_reports/115562499.pdf...
# Processing iucn_reports/182235113.pdf...
# Processing iucn_reports/115561431.pdf...
# Processing iucn_reports/189740044.pdf...
# Processing iucn_reports/115581600.pdf...
# Processing iucn_reports/115562696.pdf...
# Processing iucn_reports/182235685.pdf...
# Processing iucn_reports/182236363.pdf...
# Processing iucn_reports/115564398.pdf...
# Processing iucn_reports/115564580.pdf...
# Processing iucn_reports/115582831.pdf...
# Processing iucn_reports/115565375.pdf...
# Processing iucn_reports/115565760.pdf...
# Processing iucn_reports/115564770.pdf...
# Processing iucn_reports/115574598.pdf...
# Processing iucn_reports/115574178.pdf...
# Processing iucn_reports/115582704.pdf...
# Processing iucn_reports/196465915.pdf...
# Processing iucn_reports/115585357.pdf...
# Processing iucn_reports/115584379.pdf...
# Processing iucn_reports/210368927.pdf...
# Processing iucn_reports/115566145.pdf...
# Processing iucn_reports/115581448.pdf...
# Processing iucn_reports/115585939.pdf...
# Processing iucn_reports/115587841.pdf...
# Processing iucn_reports/115585671.pdf...
# Processing iucn_reports/115583306.pdf...
# Processing iucn_reports/115566334.pdf...
# Processing iucn_reports/115566492.pdf...
# Processing iucn_reports/115583605.pdf...
# Processing iucn_reports/207130315.pdf...
# Processing iucn_reports/115586218.pdf...
# Processing iucn_reports/115584740.pdf...
# Processing iucn_reports/115581313.pdf...
# Processing iucn_reports/115566869.pdf...
# Processing iucn_reports/115584072.pdf...
# Processing iucn_reports/115587981.pdf...
# Processing iucn_reports/115585037.pdf...
# Processing iucn_reports/115567059.pdf...
# Processing iucn_reports/115585199.pdf...
# Processing iucn_reports/115582103.pdf...
# Processing iucn_reports/17971784.pdf...
# Data saved to iucn_extracted_raw_data.csv

# %% [markdown]
# # Work From Here..

# %%
import pandas as pd
raw_df = pd.read_csv('iucn_extracted_raw_data.csv')

# %% [markdown]
# #6. Cleaning the raw csv data:

# %% [markdown]
# ### A. First, cleaning the 'Red List Category' column:

# %%
raw_df.head()
# Out:
#                                     Scientific Name  \
# 0   Zaglossus attenboroughi Flannery & Groves, 1998
# 1                  Zaglossus bartoni (Thomas, 1907)
# 2         Zaglossus bruijnii (Peters & Doria, 1876)
# 3              Caenolestes caniventer Anthony, 1921
# 4  Caenolestes condorensis Albuja & Patterson, 1996
#
#                                             Taxonomy  \
# 0  Animalia Chordata Mammalia Monotremata Tachygl...
# 1  Animalia Chordata Mammalia Monotremata Tachygl...
# 2  Animalia Chordata Mammalia Monotremata Tachygl...
# 3  Animalia Chordata Mammalia Paucituberculata Ca...
# 4  Animalia Chordata Mammalia Paucituberculata Ca...
#
#                         Red List Category & Criteria  Date Assessed  \
# 0  Critically Endangered B1ab(iii,v)+2ab(iii,v) v...  July 24, 2015
# 1                            Vulnerable A2cd ver 3.1  July 24, 2015
# 2                Critically Endangered A2acd ver 3.1  July 24, 2015
# 3                            Near Threatened ver 3.1   May 14, 2015
# 4                            Vulnerable D1+2 ver 3.1  March 1, 2015
#
#    Year Published Current Population Trend      Systems  \
# 0            2016               Decreasing  Terrestrial
# 1            2016               Decreasing  Terrestrial
# 2            2016               Decreasing  Terrestrial
# 3            2015               Decreasing  Terrestrial
# 4            2015                  Unknown  Terrestrial
#
#                                    Range Description  \
# 0  This species is known from one specimen collec...
# 1  This species ranges throughout the central mou...
# 2  This species is recorded only from the Vogelko...
# 3  This species is found in western Ecuador and n...
# 4  This species is only found in one locality in ...
#
#                                  Habitat and Ecology  \
# 0  (see Appendix for additional information)\nThe...
# 1  (see Appendix for additional information)\nThi...
# 2  (see Appendix for additional information)\nThi...
# 3  (see Appendix for additional information)\nThi...
# 4  (see Appendix for additional information)\nThe...
#
#                                              Threats
# 0  (see Appendix for additional information)\nAll...
# 1  (see Appendix for additional information)\nAll...
# 2  (see Appendix for additional information)\nAll...
# 3  (see Appendix for additional information)\nThe...
# 4  (see Appendix for additional information)\nPla...

# %%
# raw_df['Red List Category & Criteria'].unique()

# %%
cleaned_df = raw_df.copy() # just copying so that I have both versions.

# %%
cleaned_df['Red List Category & Criteria'] = cleaned_df['Red List Category & Criteria'].apply(
    lambda x: (
        'critically_endangered' if 'Critically Endangered' in x else
        'endangered' if 'Endangered' in x else
        'vulnerable' if 'Vulnerable' in x else
        'near_threatened' if 'Near Threatened' in x else
        'least_concern' if 'Least Concern' in x else
        'data_deficient' if 'Data Deficient' in x else
        'extinct' if 'Extinct' in x else x

    )
)

# %%
cleaned_df['Red List Category & Criteria'].unique()
# Out:
# array(['critically_endangered', 'vulnerable', 'near_threatened',
#        'least_concern', 'data_deficient', 'endangered', 'extinct'],
#       dtype=object)

# %% [markdown]
# ### B. Cleaning Habitat and Ecology, and Threats:

# %%
cleaned_df['Habitat and Ecology']  = cleaned_df['Habitat and Ecology'].str.replace(r'\(see Appendix for additional information\)', '', regex=True)
cleaned_df['Habitat and Ecology']  = cleaned_df['Habitat and Ecology'].str.replace(r'\n', '', regex=True)
# cleaned_df['Habitat and Ecology']

# %%
cleaned_df['Threats']  = cleaned_df['Threats'].str.replace(r'\(see Appendix for additional information\)', '', regex=True)
cleaned_df['Threats']  = cleaned_df['Threats'].str.replace(r'\n', '', regex=True)
cleaned_df['Threats']
# Out:
# 0      All long-beaked echidnas Zaglossus are highly ...
# 1      All long-beaked echidnas Zaglossus are highly ...
# 2      All long-beaked echidnas Zaglossus are highly ...
# 3      The major threat to this species is deforestation
# 4      Plausible threats could include land conversio...
#                              ...
# 900    Hunting of this species is unsustainable (Gold...
# 901    The major threat is forest loss due to illicit...
# 902    This species is threatened by habitat loss and...
# 903    The entirety of this species’ known distributi...
# 904    The reasons for the extinction are not known, ...
# Name: Threats, Length: 905, dtype: object

# %% [markdown]
# ### C. Cleaning scientific Name column:

# %%
print(cleaned_df['Scientific Name'])
# Out:
# 0        Zaglossus attenboroughi Flannery & Groves, 1998
# 1                       Zaglossus bartoni (Thomas, 1907)
# 2              Zaglossus bruijnii (Peters & Doria, 1876)
# 3                   Caenolestes caniventer Anthony, 1921
# 4       Caenolestes condorensis Albuja & Patterson, 1996
#                              ...
# 900    Lepilemur seali Louis Jr., Engberg, Lei, Geng,...
# 901    Lepilemur septentrionalis Rumpler & Albignac, ...
# 902    Lepilemur tymerlachsoni Louis Jr., Engberg, Le...
# 903    Lepilemur wrightae Louis Jr., Engberg, Lei, Ge...
# 904         Palaeopropithecus ingens G. Grandidier, 1899
# Name: Scientific Name, Length: 905, dtype: object

# %%
cleaned_df['Scientific Name'] = cleaned_df['Scientific Name'].str.split().str[:2].str.join(' ')

# %%
cleaned_df[cleaned_df['Scientific Name'].duplicated(keep=False)]
# keep=False includes both the first occurrence and the subsequent occurrence.
# Out:
#                 Scientific Name  \
# 100      Dasycercus cristicauda
# 101      Dasycercus cristicauda
# 590  Trachypithecus hatinhensis
# 594  Trachypithecus hatinhensis
# 762              Cacajao calvus
# 765              Cacajao calvus
# 766              Cacajao calvus
# 767              Cacajao calvus
#
#                                               Taxonomy  \
# 100  Animalia Chordata Mammalia Dasyuromorphia Dasy...
# 101  Animalia Chordata Mammalia Dasyuromorphia Dasy...
# 590  Animalia Chordata Mammalia Primates Cercopithe...
# 594  Animalia Chordata Mammalia Primates Cercopithe...
# 762    Animalia Chordata Mammalia Primates Pitheciidae
# 765    Animalia Chordata Mammalia Primates Pitheciidae
# 766    Animalia Chordata Mammalia Primates Pitheciidae
# 767    Animalia Chordata Mammalia Primates Pitheciidae
#
#     Red List Category & Criteria      Date Assessed  Year Published  \
# 100              near_threatened     March 18, 2014            2016
# 101              near_threatened     March 18, 2014            2016
# 590                   endangered  November 21, 2015            2021
# 594                   endangered  November 21, 2015            2021
# 762                least_concern      March 6, 2020            2022
# 765                   vulnerable   January 26, 2015            2022
# 766                least_concern    August 14, 2021            2021
# 767                   vulnerable    August 28, 2021            2021
#
#     Current Population Trend      Systems  \
# 100                   Stable  Terrestrial
# 101                   Stable  Terrestrial
# 590               Decreasing  Terrestrial
# 594               Decreasing  Terrestrial
# 762                   Stable  Terrestrial
# 765               Decreasing  Terrestrial
# 766               Decreasing  Terrestrial
# 767               Decreasing  Terrestrial
#
#                                      Range Description  \
# 100  The Crest-tailed Mulgara has (or had) a wide d...
# 101  The Crest-tailed Mulgara has (or had) a wide d...
# 590  The Ha Tinh Langur occurs in limestone areas i...
# 594  The Ha Tinh Langur occurs in limestone areas i...
# 762  The geographic distribution of Cacajao calvus ...
# 765  © The IUCN Red List of Threatened Species: Cac...
# 766  Cacajao calvus rubicundus is endemic to Brazil...
# 767  Cacajao calvus ucayalii is found south of the ...
#
#                                    Habitat and Ecology  \
# 100  The Crest-tailed Mulgara is a mostly nocturnal...
# 101  The Crest-tailed Mulgara is a mostly nocturnal...
# 590  This species is typically found in forested ha...
# 594  This species is typically found in forested ha...
# 762  Most of the available information on the ecolo...
# 765  No field data on ecology are available for thi...
# 766  Other forms of Cacajao calvus inhabit varzea h...
# 767  Occurs in flooded forests, low to medium hill ...
#
#                                                Threats
# 100  Threats are poorly understood but include pred...
# 101  Threats are poorly understood but include pred...
# 590  The main threat to this species is hunting, as...
# 594  The main threat to this species is hunting, as...
# 762  Habitat loss is the principal threat to this s...
# 765  The subspecies has a restricted range between ...
# 766                 There are no evident threats for C
# 767  Habitat loss and hunting are the main threats ...

# %%
cleaned_df = cleaned_df.drop_duplicates().reset_index(drop=True)

# %%
cleaned_df.to_csv('cleaned_df.csv')
